# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import scipy 
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
print(tf.test.is_gpu_available())
print(tf.test.is_built_with_cuda())
print(tf.test.gpu_device_name())
# Out:
# 2.0.0-beta0
# False
# False

# %%
import os

### Make sure our data is in order
data_base_dir = "../data"
figs_base_dir = "../figs"

original_data_path = data_base_dir + "/original/symbol/"
processed_data_path = data_base_dir + "/processed/symbol/"
pickle_data_path = data_base_dir + "/pickle/symbol/"

assert os.path.exists(original_data_path), "Original data path does not exist."
assert os.path.isdir(processed_data_path), "Original data path exists, but is not a directory."

if not os.path.exists(processed_data_path):
    print("Creating processed data path...")
    os.mkdir(processed_data_path)

# %% [markdown]
# ## Load data
#
# Below, we unpickle the data.

# %%
import pickle 

with open(f"{pickle_data_path}labels.pickle", 'rb') as handle:
    unique_labels = pickle.load(handle)
    unique_labels.sort()

with open(f"{pickle_data_path}train_labels.pickle", 'rb') as handle:
    train_labels = pickle.load(handle)
    
with open(f"{pickle_data_path}train_images.pickle", 'rb') as handle:
    train_images = pickle.load(handle)
    
with open(f"{pickle_data_path}test_labels.pickle", 'rb') as handle:
    test_labels = pickle.load(handle)
    
with open(f"{pickle_data_path}test_images.pickle", 'rb') as handle:
    test_images = pickle.load(handle)
    
print("Data loading complete.")
print(f"Got {len(train_images)} training images and {len(train_labels)} labels.")
print(f"Got {len(test_images)} test images and {len(test_labels)} labels.")
print(f"Found {len(unique_labels)} total unique labels.")
# Out:
# Data loading complete.
# Got 85412 training images and 85412 labels.
# Got 9987 training images and 9987 labels.
# Found 101 total unique labels.

# %% [markdown]
# Next, plot some sample images from the training dataset:

# %%
import random 

def plot_indices(indices, images, labels, label_category_names, size=(128,128), metadata=None, save=False, name=None):   
    fig, ax = plt.subplots(nrows=3, ncols=3, figsize=(10,10))
    index = 0
    for row in ax:
        for col in row:
            # Get image & label
            idx = indices[index]
            image = tf.reshape(images[idx], size)
            label = labels[idx]

            if metadata is not None:
                meta = f"meta={metadata[index]}"
            else:
                meta = ''
                    

            col.tick_params(
                axis='both',        
                which='both',
                left=False,
                right=False,
                bottom=False,
                top=False,   
                labelbottom=False,
            )
            col.imshow(image, cmap='gray', vmin=0, vmax=1.0)
            col.set_title(f"gt_label={label}\n{meta}")

            index += 1
            
    if save and name is not None:
        print("Saving figure...")
        plt.savefig(name)
        
# Plot some random images
random_indices = [random.randint(0, len(train_images)) for i in range(0,9)]
plot_indices(random_indices, train_images, train_labels, unique_labels)

# %%
# Convert from label to category
train_cat = [unique_labels.index(label) for label in train_labels]
test_cat = [unique_labels.index(label) for label in test_labels]

# %% [markdown]
# ### Simple Binary classification model
#
# As a basic sanity check, lets train a simple binary classication model that predicts if an image contains a '-' symbol.
# We will use a model with 2 dense layers trained with the Adam optimizer and a binary cross-entropy loss function (as appropriate for binary classifcation).
# The performance of this model should provide an upper bound on the performance we can expect for a k-class classification model.

# %%
from tensorflow.keras import models, layers

#####################################
#### Binary classification model ####
#####################################

learning_rate = 0.0001
size = (128,128)
# if model is not None:
#     del model
    
model = models.Sequential([
    layers.Flatten(input_shape=(size[0], size[1])),
    layers.Dense(128, activation='relu'),
    layers.Dense(1, activation='sigmoid')
])


model.summary()

model.compile(optimizer=tf.optimizers.Adam(learning_rate),
              loss='binary_crossentropy',
              metrics=['accuracy'])

binary_train_labels = [1 if unique_labels[label] == '-' else 0 for label in train_cat]
binary_test_labels = [1 if unique_labels[label] == '-' else 0 for label in test_cat]
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 16384)             0
# _________________________________________________________________
# dense_2 (Dense)              (None, 128)               2097280
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 129
# =================================================================
# Total params: 2,097,409
# Trainable params: 2,097,409
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(
    train_images, 
    binary_train_labels, 
    validation_data=(test_images, binary_test_labels),
    batch_size=32,
    epochs=50)
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0722 08:39:37.075514 4622980544 deprecation.py:323] From /Users/erikbeerepoot/.virtualenvs/ml-tf1/lib/python3.7/site-packages/tensorflow/python/ops/math_grad.py:1250: add_dispatch_support.<locals>.wrapper (from tensorflow.python.ops.array_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.where in 2.0, which has the same broadcast rule as np.where
# Train on 85412 samples, validate on 9987 samples
# Epoch 1/50
# 85412/85412 [==============================] - 33s 391us/sample - loss: 0.2502 - accuracy: 0.9160 - val_loss: 0.1920 - val_accuracy: 0.9149
# Epoch 2/50
# 85412/85412 [==============================] - 19s 228us/sample - loss: 0.1657 - accuracy: 0.9325 - val_loss: 0.1441 - val_accuracy: 0.9352
# Epoch 3/50
# 85412/85412 [==============================] - 19s 224us/sample - loss: 0.1492 - accuracy: 0.9393 - val_loss: 0.2170 - val_accuracy: 0.9395
# Epoch 4/50
# 85412/85412 [==============================] - 20s 237us/sample - loss: 0.1400 - accuracy: 0.9424 - val_loss: 0.1288 - val_accuracy: 0.9402
# Epoch 5/50
# 85412/85412 [==============================] - 20s 236us/sample - loss: 0.1355 - accuracy: 0.9436 - val_loss: 0.1266 - val_accuracy: 0.9486
# Epoch 6/50
# 85412/85412 [==============================] - 20s 231us/sample - loss: 0.1305 - accuracy: 0.9451 - val_loss: 0.1593 - val_accuracy: 0.9269
# Epoch 7/50
# 85412/85412 [==============================] - 21s 242us/sample - loss: 0.1299 - accuracy: 0.9455 - val_loss: 0.1357 - val_accuracy: 0.9506
# Epoch 8/50
# 85412/85412 [==============================] - 20s 230us/sample - loss: 0.1273 - accuracy: 0.9463 - val_loss: 0.1408 - val_accuracy: 0.9524
# Epoch 9/50
# 85412/85412 [==============================] - 20s 233us/sample - loss: 0.1257 - accuracy: 0.9470 - val_loss: 0.1284 - val_accuracy: 0.9376
# Epoch 10/50
# 85412/85412 [==============================] - 20s 230us/sample - loss: 0.1235 - accuracy: 0.9481 - val_loss: 0.1137 - val_accuracy: 0.9495
# Epoch 11/50
# 85412/85412 [==============================] - 20s 235us/sample - loss: 0.1172 - accuracy: 0.9510 - val_loss: 0.1179 - val_accuracy: 0.9539
# Epoch 12/50
# 85412/85412 [==============================] - 20s 231us/sample - loss: 0.1195 - accuracy: 0.9493 - val_loss: 0.1223 - val_accuracy: 0.9421
# Epoch 13/50
# 85412/85412 [==============================] - 20s 239us/sample - loss: 0.1175 - accuracy: 0.9508 - val_loss: 0.1128 - val_accuracy: 0.9533
# Epoch 14/50
# 85412/85412 [==============================] - 20s 230us/sample - loss: 0.1153 - accuracy: 0.9515 - val_loss: 0.2924 - val_accuracy: 0.9144
# Epoch 15/50
# 85412/85412 [==============================] - 20s 230us/sample - loss: 0.1174 - accuracy: 0.9514 - val_loss: 0.1122 - val_accuracy: 0.9491
# Epoch 16/50
# 85412/85412 [==============================] - 19s 226us/sample - loss: 0.1134 - accuracy: 0.9523 - val_loss: 0.1702 - val_accuracy: 0.9272
# Epoch 17/50
# 85412/85412 [==============================] - 20s 230us/sample - loss: 0.1111 - accuracy: 0.9537 - val_loss: 0.1212 - val_accuracy: 0.9429
# Epoch 18/50
# 85412/85412 [==============================] - 20s 231us/sample - loss: 0.1111 - accuracy: 0.9532 - val_loss: 0.1105 - val_accuracy: 0.9535
# Epoch 19/50
# 85412/85412 [==============================] - 20s 232us/sample - loss: 0.1099 - accuracy: 0.9545 - val_loss: 0.1109 - val_accuracy: 0.9574
# Epoch 20/50
# 85412/85412 [==============================] - 20s 233us/sample - loss: 0.1066 - accuracy: 0.9553 - val_loss: 0.1303 - val_accuracy: 0.9354
# Epoch 21/50
# 85412/85412 [==============================] - 19s 227us/sample - loss: 0.1059 - accuracy: 0.9561 - val_loss: 0.1065 - val_accuracy: 0.9557
# Epoch 22/50
# 85412/85412 [==============================] - 20s 239us/sample - loss: 0.1048 - accuracy: 0.9563 - val_loss: 0.1030 - val_accuracy: 0.9560
# Epoch 23/50
# 85412/85412 [==============================] - 19s 224us/sample - loss: 0.1062 - accuracy: 0.9560 - val_loss: 0.1049 - val_accuracy: 0.9543
# Epoch 24/50
# 85412/85412 [==============================] - 20s 229us/sample - loss: 0.1022 - accuracy: 0.9572 - val_loss: 0.1006 - val_accuracy: 0.9578
# Epoch 25/50
# 85412/85412 [==============================] - 19s 227us/sample - loss: 0.1045 - accuracy: 0.9561 - val_loss: 0.1053 - val_accuracy: 0.9594
# Epoch 26/50
# 85412/85412 [==============================] - 20s 231us/sample - loss: 0.1027 - accuracy: 0.9577 - val_loss: 0.1145 - val_accuracy: 0.9583
# Epoch 27/50
# 85412/85412 [==============================] - 19s 228us/sample - loss: 0.1026 - accuracy: 0.9571 - val_loss: 0.1001 - val_accuracy: 0.9614
# Epoch 28/50
# 85412/85412 [==============================] - 19s 227us/sample - loss: 0.1005 - accuracy: 0.9579 - val_loss: 0.1242 - val_accuracy: 0.9317
# Epoch 29/50
# 85412/85412 [==============================] - 19s 227us/sample - loss: 0.0992 - accuracy: 0.9589 - val_loss: 0.1235 - val_accuracy: 0.9447
# Epoch 30/50
# 85412/85412 [==============================] - 19s 226us/sample - loss: 0.0982 - accuracy: 0.9605 - val_loss: 0.1046 - val_accuracy: 0.9548
# Epoch 31/50
# 85412/85412 [==============================] - 20s 232us/sample - loss: 0.0966 - accuracy: 0.9604 - val_loss: 0.0996 - val_accuracy: 0.9576
# Epoch 32/50
# 85412/85412 [==============================] - 19s 226us/sample - loss: 0.0983 - accuracy: 0.9592 - val_loss: 0.1380 - val_accuracy: 0.9405
# Epoch 33/50
# 85412/85412 [==============================] - 19s 227us/sample - loss: 0.0962 - accuracy: 0.9608 - val_loss: 0.1050 - val_accuracy: 0.9589
# Epoch 34/50
# 85412/85412 [==============================] - 20s 230us/sample - loss: 0.0952 - accuracy: 0.9610 - val_loss: 0.1720 - val_accuracy: 0.9321
# Epoch 35/50
# 85412/85412 [==============================] - 20s 231us/sample - loss: 0.0959 - accuracy: 0.9603 - val_loss: 0.0940 - val_accuracy: 0.9652
# Epoch 36/50
# 85412/85412 [==============================] - 20s 230us/sample - loss: 0.0938 - accuracy: 0.9620 - val_loss: 0.1070 - val_accuracy: 0.9433
# Epoch 37/50
# 85412/85412 [==============================] - 20s 233us/sample - loss: 0.0938 - accuracy: 0.9619 - val_loss: 0.1086 - val_accuracy: 0.9580
# Epoch 38/50
# 85412/85412 [==============================] - 20s 231us/sample - loss: 0.0927 - accuracy: 0.9627 - val_loss: 0.0974 - val_accuracy: 0.9582
# Epoch 39/50
# 85412/85412 [==============================] - 20s 231us/sample - loss: 0.0912 - accuracy: 0.9628 - val_loss: 0.0955 - val_accuracy: 0.9642
# Epoch 40/50
# 85412/85412 [==============================] - 19s 226us/sample - loss: 0.0901 - accuracy: 0.9635 - val_loss: 0.1047 - val_accuracy: 0.9597
# Epoch 41/50
# 85412/85412 [==============================] - 19s 224us/sample - loss: 0.0910 - accuracy: 0.9641 - val_loss: 0.0919 - val_accuracy: 0.9627
# Epoch 42/50
# 85412/85412 [==============================] - 20s 232us/sample - loss: 0.0905 - accuracy: 0.9638 - val_loss: 0.0903 - val_accuracy: 0.9685
# Epoch 43/50
# 85412/85412 [==============================] - 20s 228us/sample - loss: 0.0876 - accuracy: 0.9654 - val_loss: 0.0902 - val_accuracy: 0.9656
# Epoch 44/50
# 85412/85412 [==============================] - 20s 233us/sample - loss: 0.0880 - accuracy: 0.9650 - val_loss: 0.0952 - val_accuracy: 0.9597
# Epoch 45/50
# 85412/85412 [==============================] - 20s 233us/sample - loss: 0.0870 - accuracy: 0.9662 - val_loss: 0.0954 - val_accuracy: 0.9649
# Epoch 46/50
# 85412/85412 [==============================] - 21s 241us/sample - loss: 0.0862 - accuracy: 0.9659 - val_loss: 0.1430 - val_accuracy: 0.9412
# Epoch 47/50
# 85412/85412 [==============================] - 21s 241us/sample - loss: 0.0853 - accuracy: 0.9669 - val_loss: 0.1023 - val_accuracy: 0.9608
# Epoch 48/50
# 85412/85412 [==============================] - 19s 226us/sample - loss: 0.0871 - accuracy: 0.9667 - val_loss: 0.1319 - val_accuracy: 0.9493
# Epoch 49/50
# 85412/85412 [==============================] - 20s 231us/sample - loss: 0.0854 - accuracy: 0.9663 - val_loss: 0.0864 - val_accuracy: 0.9707
# Epoch 50/50
# 85412/85412 [==============================] - 21s 241us/sample - loss: 0.0843 - accuracy: 0.9668 - val_loss: 0.1202 - val_accuracy: 0.9533

# %%
import pandas as pd
def plot_history(history, filename=None):
    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Accuracy')
    plt.plot(hist['epoch'], hist['accuracy'], label='Accuracy')
    plt.plot(hist['epoch'], hist['val_accuracy'], label='Validation accuracy')

    plt.title("Figure 2: Training and validation loss vs. Epoch")
    plt.legend()

    if filename is not None:
        plt.savefig(f"{figs_base_dir}{filename}")        
        
    plt.show()

# %% [markdown]
# From the training plot below, at 50 epochs, we can see the training curve has not quite levelled out. Hence,
# we can improve our results by increasing the training time.

# %%
plot_history(history, "sybmol-accuracy.pdf")

# %% [markdown]
# Now, let's plot some sample predictions along with the ground truth labels and associated confidence to emperically gauge
# the quality of the predictions made.

# %%
# Select some random images from the training set
random_indices = [random.randint(0, len(test_images)) for i in range(0,9)]

# Predict the labels
random_images = np.array([test_images[idx] for idx in random_indices])
predictions = model.predict(random_images)

# Plot
plot_indices(random_indices, test_images, test_labels, unique_labels, metadata=predictions)

# %% [markdown]
# We can observe that the model is able to predict the correct label with confidence, but is prone to false positives.
#
# Now, let's try a more complicated model.

# %% [markdown]
# ## Binary classification with Convolutional Neural nets

# %%
# Add CNNs for features
model = models.Sequential()
model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(size[0], size[1], 1)))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))
model.add(layers.MaxPooling2D((2, 2)))
model.add(layers.Conv2D(64, (3, 3), activation='relu'))

# Add dense layers for classification
model.add(layers.Flatten(input_shape=(size[0], size[1], 1)))
model.add(layers.Dense(25, activation='relu'))
model.add(layers.Dense(1, activation='sigmoid'))

model.compile(optimizer=tf.optimizers.Adam(learning_rate),
              loss='binary_crossentropy',
              metrics=['accuracy'])

model.summary()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-65-eb32b1f7490f> in <module>
#       1 # Add CNNs for features
#       2 model = models.Sequential()
# ----> 3 model.add(layers.Conv2D(32, (3, 3), activation='relu', input_shape=(size[0], size[1])))
#       4 model.add(layers.MaxPooling2D((2, 2)))
#       5 model.add(layers.Conv2D(64, (3, 3), activation='relu'))
#
# ~/.virtualenvs/ml-tf1/lib/python3.7/site-packages/tensorflow/python/training/tracking/base.py in _method_wrapper(self, *args, **kwargs)
#     456     self._self_setattr_tracking = False  # pylint: disable=protected-access
#     457     try:
# --> 458       result = method(self, *args, **kwargs)
#     459     finally:
#     460       self._self_setattr_tracking = previous_value  # pylint: disable=protected-access
#
# ~/.virtualenvs/ml-tf1/lib/python3.7/site-packages/tensorflow/python/keras/engine/sequential.py in add(self, layer)
#     173           # and create the node connecting the current layer
#     174           # to the input layer we just created.
# --> 175           layer(x)
#     176           set_inputs = True
#     177
#
# ~/.virtualenvs/ml-tf1/lib/python3.7/site-packages/tensorflow/python/keras/engine/base_layer.py in __call__(self, inputs, *args, **kwargs)
#     609         # the corresponding TF subgraph inside `backend.get_graph()`
#     610         input_spec.assert_input_compatibility(self.input_spec, inputs,
# --> 611                                               self.name)
#     612         graph = backend.get_graph()
#     613         with graph.as_default(), backend.name_scope(self._name_scope()):
#
# ~/.virtualenvs/ml-tf1/lib/python3.7/site-packages/tensorflow/python/keras/engine/input_spec.py in assert_input_compatibility(input_spec, inputs, layer_name)
#     173                          'expected ndim=' + str(spec.ndim) + ', found ndim=' +
#     174                          str(ndim) + '. Full shape received: ' +
# --> 175                          str(x.shape.as_list()))
#     176     if spec.max_ndim is not None:
#     177       ndim = x.shape.ndims
#
# ValueError: Input 0 of layer conv2d_15 is incompatible with the layer: expected ndim=4, found ndim=3. Full shape received: [None, 128, 128]

# %%
history = model.fit(
    train_images, 
    binary_train_labels, 
    validation_data=(test_images, binary_test_labels),
    batch_size=32,
    epochs=50)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-64-81d432308660> in <module>
#       4     validation_data=(test_images, binary_test_labels),
#       5     batch_size=32,
# ----> 6     epochs=50)
#
# ~/.virtualenvs/ml-tf1/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, max_queue_size, workers, use_multiprocessing, **kwargs)
#     641         max_queue_size=max_queue_size,
#     642         workers=workers,
# --> 643         use_multiprocessing=use_multiprocessing)
#     644
#     645   def evaluate(self,
#
# ~/.virtualenvs/ml-tf1/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_arrays.py in fit(self, model, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_freq, **kwargs)
#     630         steps=steps_per_epoch,
#     631         validation_split=validation_split,
# --> 632         shuffle=shuffle)
#     633
#     634     if validation_data:
#
# ~/.virtualenvs/ml-tf1/lib/python3.7/site-packages/tensorflow/python/keras/engine/training.py in _standardize_user_data(self, x, y, sample_weight, class_weight, batch_size, check_steps, steps_name, steps, validation_split, shuffle, extract_tensors_from_dataset)
#    2426           feed_input_shapes,
#    2427           check_batch_axis=False,  # Don't enforce the batch size.
# -> 2428           exception_prefix='input')
#    2429
#    2430     if y is not None:
#
# ~/.virtualenvs/ml-tf1/lib/python3.7/site-packages/tensorflow/python/keras/engine/training_utils.py in standardize_input_data(data, names, shapes, check_batch_axis, exception_prefix)
#     510                            ': expected ' + names[i] + ' to have ' +
#     511                            str(len(shape)) + ' dimensions, but got array '
# --> 512                            'with shape ' + str(data_shape))
#     513         if not check_batch_axis:
#     514           data_shape = data_shape[1:]
#
# ValueError: Error when checking input: expected conv2d_12_input to have 4 dimensions, but got array with shape (85412, 128, 128)
