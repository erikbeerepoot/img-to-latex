# %%
import tensorflow as tf
import numpy as np
import pandas as pd
import scipy 
import matplotlib.pyplot as plt

# %%
print(tf.__version__)
print(tf.test.is_gpu_available())
print(tf.test.is_built_with_cuda())
print(tf.test.gpu_device_name())
# Out:
# 2.0.0-beta0
# False
# False

# %%
import os

### Make sure our data is in order
data_base_dir = "../data"
figs_base_dir = "../figs"

original_data_path = data_base_dir + "/original/formula/"
processed_data_path = data_base_dir + "/processed/formula/"
pickle_data_path = data_base_dir + "/pickle/formula/"

assert os.path.exists(original_data_path), "Original data path does not exist."
assert os.path.isdir(processed_data_path), "Original data path exists, but is not a directory."

if not os.path.exists(processed_data_path):
    print("Creating processed data path...")
    os.mkdir(processed_data_path)

# %% [markdown]
# ## Load data
#
# Below, we unpickle the data.

# %%
import pickle 

with open(f"{pickle_data_path}vocab.pickle", 'rb') as handle:
    wordlist = pickle.load(handle)

with open(f"{pickle_data_path}train_labels.pickle", 'rb') as handle:
    train_labels = pickle.load(handle)
    
with open(f"{pickle_data_path}train_images.pickle", 'rb') as handle:
    train_images = pickle.load(handle)
    
with open(f"{pickle_data_path}validation_labels.pickle", 'rb') as handle:
    validation_labels = pickle.load(handle)
    
with open(f"{pickle_data_path}validation_images.pickle", 'rb') as handle:
    validation_images = pickle.load(handle)
    
with open(f"{pickle_data_path}test_labels.pickle", 'rb') as handle:
    test_labels = pickle.load(handle)
    
with open(f"{pickle_data_path}test_images.pickle", 'rb') as handle:
    test_images = pickle.load(handle)
    
print("Data loading complete.")
print(f"Got {len(train_images)} training images and {len(train_labels)} labels.")
print(f"Got {len(validation_images)} validation images and {len(validation_labels)} labels.")
print(f"Got {len(test_images)} validation images and {len(test_labels)} labels.")
print(f"Vocab length: {len(wordlist)}.")
# Out:
# Data loading complete.
# Got 76303 training images and 76303 labels.
# Got 8474 validation images and 8474 labels.
# Got 9442 validation images and 9442 labels.
# Vocab length: 510.

# %%
import random 
import matplotlib.pyplot as plt

# Plot some random images & labels
# so we can ensure correctness
random_indices = [random.randint(0, len(train_images)) for i in range(0,5)]

for index in random_indices:
    plt.figure(figsize=(10,10))
    plt.imshow(train_images[index], cmap='gray')
    plt.title(train_labels[index])
    plt.show()

# %% [markdown]
# ## Attention model

# %%
from __future__ import division
import math
import numpy as np
from six.moves import xrange
import tensorflow as tf


# taken from https://github.com/tensorflow/tensor2tensor/blob/37465a1759e278e8f073cd04cd9b4fe377d3c740/tensor2tensor/layers/common_attention.py


def add_timing_signal_nd(x, min_timescale=1.0, max_timescale=1.0e4):
    """Adds a bunch of sinusoids of different frequencies to a Tensor.

    Each channel of the input Tensor is incremented by a sinusoid of a difft
    frequency and phase in one of the positional dimensions.

    This allows attention to learn to use absolute and relative positions.
    Timing signals should be added to some precursors of both the query and the
    memory inputs to attention.

    The use of relative position is possible because sin(a+b) and cos(a+b) can
    be expressed in terms of b, sin(a) and cos(a).

    x is a Tensor with n "positional" dimensions, e.g. one dimension for a
    sequence or two dimensions for an image

    We use a geometric sequence of timescales starting with
    min_timescale and ending with max_timescale.  The number of different
    timescales is equal to channels // (n * 2). For each timescale, we
    generate the two sinusoidal signals sin(timestep/timescale) and
    cos(timestep/timescale).  All of these sinusoids are concatenated in
    the channels dimension.

    Args:
        x: a Tensor with shape [batch, d1 ... dn, channels]
        min_timescale: a float
        max_timescale: a float

    Returns:
        a Tensor the same shape as x.

    """
    static_shape = x.get_shape().as_list()
    num_dims = len(static_shape) - 2
    channels = tf.shape(x)[-1]
    num_timescales = channels // (num_dims * 2)
    log_timescale_increment = (
            math.log(float(max_timescale) / float(min_timescale)) /
            (tf.cast(num_timescales, tf.float32) - 1))
    inv_timescales = min_timescale * tf.exp(
            tf.cast(tf.range(num_timescales), tf.float32) * -log_timescale_increment)
    for dim in xrange(num_dims):
        length = tf.shape(x)[dim + 1]
        position = tf.cast(tf.range(length), tf.float32)
        scaled_time = tf.expand_dims(position, 1) * tf.expand_dims(
                inv_timescales, 0)
        signal = tf.concat([tf.sin(scaled_time), tf.cos(scaled_time)], axis=1)
        prepad = dim * 2 * num_timescales
        postpad = channels - (dim + 1) * 2 * num_timescales
        signal = tf.pad(signal, [[0, 0], [prepad, postpad]])
        for _ in xrange(1 + dim):
            signal = tf.expand_dims(signal, 0)
        for _ in xrange(num_dims - 1 - dim):
            signal = tf.expand_dims(signal, -2)
        x += signal
    return x

# %%
from tensorflow.keras import metrics, layers, Model

class BahdanauAttention(layers.Layer):
    def __init__(self, units):
        super(BahdanauAttention, self).__init__()
        self.W1 = tf.keras.layers.Dense(units)
        self.W2 = tf.keras.layers.Dense(units)
        self.V = tf.keras.layers.Dense(1)
        
    def call(self, features, hidden):
        # First, flatten the image
        shape = tf.shape(features)
        if len(shape) == 4:
            batch_size = shape[0]
            img_height = shape[1]
            img_width  = shape[2]
            channels   = shape[3]
            features = tf.reshape(features, shape=(batch_size, img_height*img_width, channels))
        else:
            print(f"Image shape not supported: {shape}.")
            raise NotImplementedError
        
        # features(CNN_encoder_output)
        # shape => (batch_size, flattened_image_size, embedding_size)
        
        # hidden shape == (batch_size, hidden_size)
        # hidden_with_time_axis shape == (batch_size, 1, hidden_size)
        hidden_with_time_axis = tf.expand_dims(hidden, 1)

        # score 
        # shape => (batch_size, flattened_image_size, hidden_size)
        score = tf.nn.tanh(self.W1(features)) + self.W2(hidden_with_time_axis)
        
        # attention_weights
        # shape => (batch_size, flattened_image_Size, 1)
        attention_weights = tf.nn.softmax(self.V(score), axis=1)
        
        # context_vector
        # shape after sum => (batch_size, hidden_size)
        context_vector = attention_weights * features
        context_vector = tf.reduce_sum(context_vector, axis=1)
        
        return context_vector, attention_weights

# %%
class CNNEncoder(tf.keras.Model):    
    def __init__(self, embedding_dim):
        super(CNNEncoder, self).__init__()
        
        self.fc = tf.keras.layers.Dense(embedding_dim)
        
    def build(self, input_shape):       
        self.cnn_1 = layers.Conv2D(32, (3, 3), activation='relu', input_shape=(input_shape[1], input_shape[2], 1))
        self.max_pool_1 = layers.MaxPooling2D((2, 2))
        
        self.cnn_2 = layers.Conv2D(64, (3, 3), activation='relu')
        self.max_pool_2 = layers.MaxPooling2D((2, 2))
        
        self.cnn_3 = layers.Conv2D(64, (3, 3), activation='relu')

        
    def call(self, images):
        images = tf.cast(images, tf.float32)
        x = self.cnn_1(images)
        x = self.max_pool_1(x)
        x = self.cnn_2(x)
        x = self.max_pool_2(x)
        return self.cnn_3(x)
        # x = self.cnn_3(x)
        #return add_timing_signal_nd(x)

# %%
class Vocab(object):
    def __init__(self, vocab_path):
        self.build_vocab(vocab_path)
        
    def build_vocab(self, vocab_path):
        '''
        Builds the complete vocabulary, including special tokens
        '''
        self.unk   = "<UNK>"
        self.start = "<SOS>"
        self.end   = "<END>"
        self.pad   = "<PAD>"
        
        # First, load our vocab from disk & determine 
        # highest index in mapping.
        vocab = self.load_vocab(vocab_path)
        max_index = max(vocab.values())
        
        # Compile special token mapping
        special_tokens = {
            self.unk : max_index + 1,
            self.start : max_index + 2,
            self.end : max_index + 3,
            self.pad : max_index + 4
        }
        
        # Merge dicts to produce final word index
        self.token_index = {**vocab, **special_tokens}
    
    def load_vocab(self, vocab_path):
        '''
        Load vocabulary from file
        '''
        token_index = {}
        with open(vocab_path) as f:
            for idx, token in enumerate(f):
                token = token.strip()
                token_index[token] = idx
        assert len(token_index) > 0, "Could not build word index"
        return token_index
                
    def tokenize_formula(self, formula):
        '''
        Converts a formula into a sequence of tokens using the vocabulary
        '''
        def lookup_token(token):
            return self.token_index[token] if token in self.token_index else self.token_index[self.unk]
        tokens = formula.strip().split(' ')        
        return list(map(lambda f: lookup_token(f), tokens))
        
    def pad_formula(self, formula, max_length):
        '''
        Pads a formula to max_length with pad_token, appending end_token.
        '''
        # Extra space for the end token
        padded_formula = self.token_index[self.pad] * np.ones(max_length + 1)
        padded_formula[:len(formula)] = formula
        padded_formula[-1] = self.token_index[self.end]
        return padded_formula

    @property
    def length(self):
        return len(self.token_index)
    
vocab = Vocab(f"{processed_data_path}/vocab.txt")

# %%
BATCH_SIZE = 32
BUFFER_SIZE = 500
embedding_dim = 128
vocab_size = vocab.length
hidden_units = 128

lbs = train_labels[0:512]
ims = train_images[0:512]

num_steps = len(ims) 

ims = [np.expand_dims(im, -1) for im in ims]
lbs = [vocab.tokenize_formula(lbl) for lbl in lbs]

max_formula_length = max([len(lbl) for lbl in lbs])
padded_lbs = [vocab.pad_formula(lbl, max_formula_length) for lbl in lbs]

dataset = tf.data.Dataset.from_tensor_slices((ims, padded_lbs))

# Shuffle and batch
dataset = dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
dataset = dataset.prefetch(buffer_size=tf.data.experimental.AUTOTUNE)

# %%
class RNNDecoder(tf.keras.Model):
    def __init__(self, embedding_dim, units, vocab_size):
        super(RNNDecoder, self).__init__()
        self.units = units
        
        self.embedding = tf.keras.layers.Embedding(vocab_size, embedding_dim)
        self.gru = tf.keras.layers.GRU(self.units,
                                       return_sequences=True,
                                       return_state=True,
                                       recurrent_initializer='glorot_uniform')
        
        self.fc1 = tf.keras.layers.Dense(self.units)
        self.fc2 = tf.keras.layers.Dense(vocab_size)

        self.attention = BahdanauAttention(self.units)

        
    def call(self, x, features, hidden):        
        # attend over the image features
        context_vector, attention_weights = self.attention(features, hidden)
        
        # convert our input vector to an embedding
        x = self.embedding(x)
                
        # concat the embedding and the context vector (from attention)
        x = tf.concat([tf.expand_dims(context_vector, 1), x], axis=-1)
        
        # pass to GRU
        output, state = self.gru(x)
        
        x = self.fc1(output)
        
        x = tf.reshape(x, (-1, x.shape[2]))
        
        # This produces a distribution over the vocab
        x = self.fc2(x)
        
        return x, state, attention_weights
    
    def reset_state(self, batch_size):
        return tf.zeros((batch_size, self.units))

# %%
encoder = CNNEncoder(embedding_dim=embedding_dim)
decoder = RNNDecoder(embedding_dim, hidden_units, vocab_size)

# %%
optimizer = tf.keras.optimizers.Adam()
loss_object = tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True, reduction='none')

def loss_function(real, pred):
    mask = tf.math.logical_not(tf.math.equal(real, 0))
    loss_ = loss_object(real, pred)

    mask = tf.cast(mask, dtype=loss_.dtype)
    loss_ *= mask
    return tf.reduce_mean(loss_)

# %%
checkpoint_path = "./checkpoints/train"
ckpt = tf.train.Checkpoint(encoder=encoder,
                           decoder=decoder,
                           optimizer=optimizer)
ckpt_manager = tf.train.CheckpointManager(ckpt, checkpoint_path, max_to_keep=5)

# %%
start_epoch = 0
if ckpt_manager.latest_checkpoint:
    start_epoch = int(ckpt_manager.latest_checkpoint.split('-')[-1])

# %%
# adding this in a separate cell because if you run the training cell
# many times, the loss_plot array will be reset
loss_plot = []

# %%
@tf.function
def train_step(img_tensor, target):
    loss = 0

    # initializing the hidden state for each batch
    # because the captions are not related from image to image
    hidden = decoder.reset_state(batch_size=target.shape[0])

    dec_input = tf.expand_dims([vocab.token_index['<SOS>']] * BATCH_SIZE, 1)
    
    with tf.GradientTape() as tape:
        features = encoder(img_tensor)

        for i in range(1, target.shape[1]):
            # passing the features through the decoder
            predictions, hidden, _ = decoder(dec_input, features, hidden)

            loss += loss_function(target[:, i], predictions)
            
            # using teacher forcing
            dec_input = tf.expand_dims(target[:, i], 1)

    total_loss = (loss / int(target.shape[1]))
    trainable_variables = encoder.trainable_variables + decoder.trainable_variables
    gradients = tape.gradient(loss, trainable_variables)
    optimizer.apply_gradients(zip(gradients, trainable_variables))
    return loss, total_loss

# %%
import time

EPOCHS = 20

for epoch in range(start_epoch, EPOCHS):
    start = time.time()
    total_loss = 0

    for (batch, (img_tensor, target)) in enumerate(dataset):
        batch_loss, t_loss = train_step(img_tensor, target)
        total_loss += t_loss

        if batch % 2 == 0:
            print ('Epoch {} Batch {} Loss {:.4f}'.format(
              epoch + 1, batch, batch_loss.numpy() / int(target.shape[1])))
    # storing the epoch end loss value to plot later
    loss_plot.append(total_loss / num_steps)

    if epoch % 5 == 0:
        ckpt_manager.save()

    print ('Epoch {} Loss {:.6f}'.format(epoch + 1,
                                         total_loss/num_steps))
    print ('Time taken for 1 epoch {} sec\n'.format(time.time() - start))
# Out:
# Epoch 2 Batch 0 Loss 6.5325
# Epoch 2 Batch 2 Loss 5.4871
# Epoch 2 Batch 4 Loss 4.6462
# Epoch 2 Batch 6 Loss 3.8978
# Epoch 2 Batch 8 Loss 3.1034
# Epoch 2 Batch 10 Loss 2.6979
# Epoch 2 Batch 12 Loss 2.5031
# Epoch 2 Batch 14 Loss 2.5679
# Epoch 2 Loss 0.119672
# Time taken for 1 epoch 978.7939839363098 sec
#
# Epoch 3 Batch 0 Loss 2.5086
# Epoch 3 Batch 2 Loss 2.0583
# Epoch 3 Batch 4 Loss 2.3523
# Epoch 3 Batch 6 Loss 2.2565
# Epoch 3 Batch 8 Loss 2.1411
# Epoch 3 Batch 10 Loss 2.1261
# Epoch 3 Batch 12 Loss 2.0849
# Epoch 3 Batch 14 Loss 2.1730
# Epoch 3 Loss 0.069998
# Time taken for 1 epoch 639.8619859218597 sec
#
# Epoch 4 Batch 0 Loss 2.2282
# Epoch 4 Batch 2 Loss 1.8879
# Epoch 4 Batch 4 Loss 2.2123
# Epoch 4 Batch 6 Loss 2.1691
# Epoch 4 Batch 8 Loss 2.0920
# Epoch 4 Batch 10 Loss 2.0954
# Epoch 4 Batch 12 Loss 2.0455
# Epoch 4 Batch 14 Loss 2.1273
# Epoch 4 Loss 0.067002
# Time taken for 1 epoch 640.6974189281464 sec
#
# Epoch 5 Batch 0 Loss 2.1982
# Epoch 5 Batch 2 Loss 1.8794
# Epoch 5 Batch 4 Loss 2.1933
# Epoch 5 Batch 6 Loss 2.1602
# Epoch 5 Batch 8 Loss 2.0840
# Epoch 5 Batch 10 Loss 2.0846
# Epoch 5 Batch 12 Loss 2.0403
# Epoch 5 Batch 14 Loss 2.1235
# Epoch 5 Loss 0.066552
# Time taken for 1 epoch 643.1033010482788 sec
#
# Epoch 6 Batch 0 Loss 2.1944
# Epoch 6 Batch 2 Loss 1.8728
# Epoch 6 Batch 4 Loss 2.1898
# Epoch 6 Batch 6 Loss 2.1557
# Epoch 6 Batch 8 Loss 2.0787
# Epoch 6 Batch 10 Loss 2.0798
# Epoch 6 Batch 12 Loss 2.0386
# Epoch 6 Batch 14 Loss 2.1199
# Epoch 6 Loss 0.066433
# Time taken for 1 epoch 627.1030781269073 sec
#
# Epoch 7 Batch 0 Loss 2.1915
# Epoch 7 Batch 2 Loss 1.8713
# Epoch 7 Batch 4 Loss 2.1899
# Epoch 7 Batch 6 Loss 2.1541
# Epoch 7 Batch 8 Loss 2.0779
# Epoch 7 Batch 10 Loss 2.0787
# Epoch 7 Batch 12 Loss 2.0389
# Epoch 7 Batch 14 Loss 2.1192
# Epoch 7 Loss 0.066401
# Time taken for 1 epoch 639.9576890468597 sec
#
# Epoch 8 Batch 0 Loss 2.1899
# Epoch 8 Batch 2 Loss 1.8708
# Epoch 8 Batch 4 Loss 2.1887
# Epoch 8 Batch 6 Loss 2.1549
# Epoch 8 Batch 8 Loss 2.0790
# Epoch 8 Batch 10 Loss 2.0776
# Epoch 8 Batch 12 Loss 2.0411
# Epoch 8 Batch 14 Loss 2.1209
# Epoch 8 Loss 0.066388
# Time taken for 1 epoch 635.9460580348969 sec
#
# Epoch 9 Batch 0 Loss 2.1890
# Epoch 9 Batch 2 Loss 1.8664
# Epoch 9 Batch 4 Loss 2.1904
# Epoch 9 Batch 6 Loss 2.1559
# Epoch 9 Batch 8 Loss 2.0765
# Epoch 9 Batch 10 Loss 2.0770
# Epoch 9 Batch 12 Loss 2.0406
# Epoch 9 Batch 14 Loss 2.1203
# Epoch 9 Loss 0.066373
# Time taken for 1 epoch 626.2058050632477 sec
#
# Epoch 10 Batch 0 Loss 2.1894
# Epoch 10 Batch 2 Loss 1.8674
# Epoch 10 Batch 4 Loss 2.1905
# Epoch 10 Batch 6 Loss 2.1560
# Epoch 10 Batch 8 Loss 2.0767
# Epoch 10 Batch 10 Loss 2.0769
# Epoch 10 Batch 12 Loss 2.0411
# Epoch 10 Batch 14 Loss 2.1203
# Epoch 10 Loss 0.066373
# Time taken for 1 epoch 638.900682926178 sec
#
# Epoch 11 Batch 0 Loss 2.1887
# Epoch 11 Batch 2 Loss 1.8631
# Epoch 11 Batch 4 Loss 2.1973
# Epoch 11 Batch 6 Loss 2.1583
# Epoch 11 Batch 8 Loss 2.0759
# Epoch 11 Batch 10 Loss 2.0782
# Epoch 11 Batch 12 Loss 2.0439
# Epoch 11 Batch 14 Loss 2.1203
# Epoch 11 Loss 0.066393
# Time taken for 1 epoch 634.5209350585938 sec
#
# Epoch 12 Batch 0 Loss 2.1880
# Epoch 12 Batch 2 Loss 1.8650
# Epoch 12 Batch 4 Loss 2.1936
# Epoch 12 Batch 6 Loss 2.1558
# Epoch 12 Batch 8 Loss 2.0765
# Epoch 12 Batch 10 Loss 2.0770
# Epoch 12 Batch 12 Loss 2.0430
# Epoch 12 Batch 14 Loss 2.1203
# Epoch 12 Loss 0.066370
# Time taken for 1 epoch 639.0964820384979 sec
#
# Epoch 13 Batch 0 Loss 2.1881
# Epoch 13 Batch 2 Loss 1.8634
# Epoch 13 Batch 4 Loss 2.1928
# Epoch 13 Batch 6 Loss 2.1561
# Epoch 13 Batch 8 Loss 2.0751
# Epoch 13 Batch 10 Loss 2.0768
# Epoch 13 Batch 12 Loss 2.0436
# Epoch 13 Batch 14 Loss 2.1203
# Epoch 13 Loss 0.066361
# Time taken for 1 epoch 626.8090062141418 sec
#
# Epoch 14 Batch 0 Loss 2.1877
# Epoch 14 Batch 2 Loss 1.8623
# Epoch 14 Batch 4 Loss 2.1928
# Epoch 14 Batch 6 Loss 2.1562
# Epoch 14 Batch 8 Loss 2.0753
# Epoch 14 Batch 10 Loss 2.0771
# Epoch 14 Batch 12 Loss 2.0439
# Epoch 14 Batch 14 Loss 2.1201
# Epoch 14 Loss 0.066354
# Time taken for 1 epoch 634.1228861808777 sec
#
# Epoch 15 Batch 0 Loss 2.1874
# Epoch 15 Batch 2 Loss 1.8620
# Epoch 15 Batch 4 Loss 2.1941
# Epoch 15 Batch 6 Loss 2.1555
# Epoch 15 Batch 8 Loss 2.0751
# Epoch 15 Batch 10 Loss 2.0772
# Epoch 15 Batch 12 Loss 2.0442
# Epoch 15 Batch 14 Loss 2.1197
# Epoch 15 Loss 0.066352
# Time taken for 1 epoch 645.1782240867615 sec
#
# Epoch 16 Batch 0 Loss 2.1872
# Epoch 16 Batch 2 Loss 1.8614
# Epoch 16 Batch 4 Loss 2.1941
# Epoch 16 Batch 6 Loss 2.1545
# Epoch 16 Batch 8 Loss 2.0744
# Epoch 16 Batch 10 Loss 2.0774
# Epoch 16 Batch 12 Loss 2.0409
# Epoch 16 Batch 14 Loss 2.1182
# Epoch 16 Loss 0.066333
# Time taken for 1 epoch 647.0842189788818 sec
#
# Epoch 17 Batch 0 Loss 2.1878
# Epoch 17 Batch 2 Loss 1.8614
# Epoch 17 Batch 4 Loss 2.1915
# Epoch 17 Batch 6 Loss 2.1536
# Epoch 17 Batch 8 Loss 2.0752
# Epoch 17 Batch 10 Loss 2.0771
# Epoch 17 Batch 12 Loss 2.0427
# Epoch 17 Batch 14 Loss 2.1186
# Epoch 17 Loss 0.066328
# Time taken for 1 epoch 651.129823923111 sec
#
# Epoch 18 Batch 0 Loss 2.1869
# Epoch 18 Batch 2 Loss 1.8615
# Epoch 18 Batch 4 Loss 2.1934
# Epoch 18 Batch 6 Loss 2.1543
# Epoch 18 Batch 8 Loss 2.0748
# Epoch 18 Batch 10 Loss 2.0771
# Epoch 18 Batch 12 Loss 2.0434
# Epoch 18 Batch 14 Loss 2.1187
# Epoch 18 Loss 0.066333
# Time taken for 1 epoch 637.9374318122864 sec
#
# Epoch 19 Batch 0 Loss 2.1868
# Epoch 19 Batch 2 Loss 1.8611
# Epoch 19 Batch 4 Loss 2.1936
# Epoch 19 Batch 6 Loss 2.1541
# Epoch 19 Batch 8 Loss 2.0749
# Epoch 19 Batch 10 Loss 2.0774
# Epoch 19 Batch 12 Loss 2.0435
# Epoch 19 Batch 14 Loss 2.1185
# Epoch 19 Loss 0.066332
# Time taken for 1 epoch 640.0191557407379 sec
#
# Epoch 20 Batch 0 Loss 2.1868
# Epoch 20 Batch 2 Loss 1.8606
# Epoch 20 Batch 4 Loss 2.1936
# Epoch 20 Batch 6 Loss 2.1538
# Epoch 20 Batch 8 Loss 2.0749
# Epoch 20 Batch 10 Loss 2.0774
# Epoch 20 Batch 12 Loss 2.0433
# Epoch 20 Batch 14 Loss 2.1182
# Epoch 20 Loss 0.066328
# Time taken for 1 epoch 634.8080809116364 sec
